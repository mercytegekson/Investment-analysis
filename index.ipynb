# %% [markdown]
# # Task One : Data Overview

# %% [markdown]
# This dataset is a study on investment behavior and preferences among individuals. It contains demographic information, investment choices, motivations, and expectations regarding various investment avenues.

# %% [markdown]
# # Data Description

# %% [markdown]
# ## Demographic Information:
#
# Gender: Categorizes respondents by gender, allowing analysis of investment preferences by gender.
#
# Age: Contains respondents' ages, enabling examination of how investment choices vary across age groups.
#
# ## Investment Avenues:
#
# Investment_Avenues: Likely a general category or summary of investment types chosen.
#
# Mutual_Funds: Indicates if/how much the person invests in mutual funds.
#
# Equity_Market: Tracks investments directly in equities/stocks.
#
# Debentures: Records investment in corporate bonds/debentures.
#
# Government_Bonds: Shows investment in government securities.
#
# Fixed_Deposits: Indicates money placed in bank fixed deposits.
#
# PPF: Records investment in Public Provident Fund, a government savings scheme.
#
# Gold: Tracks investment in gold (physical or paper gold).
#
# Stock_Market: Similar to Equity_Market, possibly capturing overall stock market participation.
#
# ## Investment Decision Factors:
#
# Factor: Likely captures the primary factor influencing investment decisions (e.g., risk, return, liquidity).
#
# Objective: Records the financial objective behind investments (e.g., retirement, education).
#
# Purpose: Similar to objective, may focus on specific goals for the investments.
#
# Duration: Indicates the time horizon for which investments are planned.
#
# Invest_Monitor: Shows how frequently or by what method investors track their investments.
#
# Expect: Captures expected returns or performance expectations from investments.
#
# Avenue: May represent the preferred or primary investment avenue.
#
# ## Survey Questions:
#
# What are your savings objectives?: A direct question from the survey about financial goals.
#
# Investment Reasoning:
#
# Reason_Equity: Specific reasons for choosing equity investments.
#
# Reason_Mutual: Rationale behind mutual fund investments.
#
# Reason_Bonds: Reasoning for bond investments.
#
# Reason_FD: Explanation for fixed deposit choices.
#
# ## Information Source:
#
# Source: Indicates where respondents get their investment information (e.g., financial advisors, internet, family).

# %%
import pandas as pd

# %%
data = pd.read_csv('Data_set 2 - Copy.csv')

# %%
data.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
data.dtypes
# Out:
# gender                               object
# age                                   int64
# Investment_Avenues                   object
# Mutual_Funds                          int64
# Equity_Market                         int64
# Debentures                            int64
# Government_Bonds                      int64
# Fixed_Deposits                        int64
# PPF                                   int64
# Gold                                  int64
# Stock_Marktet                        object
# Factor                               object
# Objective                            object
# Purpose                              object
# Duration                             object
# Invest_Monitor                       object
# Expect                               object
# Avenue                               object
# What are your savings objectives?    object
# Reason_Equity                        object
# Reason_Mutual                        object
# ...

# %%
data.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
data.shape
# Out:
# (40, 24)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# # Task Two : Gender Distribution

# %%
data['gender'].value_counts()
# Out:
# Male      25
# Female    15
# Name: gender, dtype: int64

# %%
import matplotlib.pyplot as plt

# Directly plot the pie chart
plt.figure(figsize=(6, 6))
plt.pie(data['gender'].value_counts().values,
        labels=data['gender'].value_counts().index,
        autopct='%1.1f%%',
        startangle=140,
        colors=['lightblue', 'pink'])

plt.title('Gender Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# Out of 40 participants , 62.5% are male while 37.5% are female.
# This implies financial literacy and investment awareness are more prevalent among men than women.

# %% [markdown]
# # Task Three : Descriptive statistics

# %%
# Extract columns with integer data type
int_columns = data.select_dtypes(include='int')
print(int_columns.columns)
# Out:
# Index(['age', 'Mutual_Funds', 'Equity_Market', 'Debentures',
#        'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold'],
#       dtype='object')

# %%
data.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %% [markdown]
# The age range is 21 to 35. Mean age of the investors is 28 . Meaning young adults are beginning to explore investment options early.
#
# Gold and Debentures are the most preferred investment avenues because of their low risks.
#
# PPF and Mutual Funds have the lowest average interest.This might be because people how low trust in pooled investments.
#
# There's variety in opinions, especially in Fixed Deposits and PPF.Younger people might be shifting toward flexible or higher return investments.

# %% [markdown]
# # Task 4: Most Preferred Investment Avenue

# %%
data['Avenue'].value_counts()
# Out:
# Mutual Fund              18
# Equity                   10
# Fixed Deposits            9
# Public Provident Fund     3
# Name: Avenue, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Get the count of each avenue type
avenue_counts = data['Avenue'].value_counts()

# Create a figure with appropriate size
plt.figure(figsize=(12, 6))

# Create the bar chart
sns.barplot(x=avenue_counts.index, y=avenue_counts.values)

# Add labels and title
plt.xlabel('Investment Avenue')
plt.ylabel('Count')
plt.title('Distribution of Investment Avenues')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Most people prefer to invest in mutual fund maybe because it is managed by a professional which removes the burden of investment decision-making from individual investors.
# The other reason may be because they have limited knowledge / expertise on how to choose individual stocks.
#
# The second preferred is Equity. Some of the reasons why equity is quite popular is because most people want higher returns and are willing to take some risks.
# It is followed slightly by Fixed deposits , it means some people prefer investing their money for short to medium terms.
# Rarely people invest in Public Provident Fund, maybe they are not interested in long terms saving schemes with tax benefits.

# %% [markdown]
# # Task 5: Reasons for Investment

# %%
data['Reason_Bonds'].value_counts()
# Out:
# Assured Returns    26
# Safe Investment    13
# Tax Incentives      1
# Name: Reason_Bonds, dtype: int64

# %%
import matplotlib.pyplot as plt

# Get the counts of each reason
bond_reasons = data['Reason_Bonds'].value_counts()

# Plotting
plt.figure(figsize=(7, 5))
plt.bar(bond_reasons.index, bond_reasons.values, color='lightgreen')

# Add labels and title
plt.title('Reasons for Investing in Bonds', fontsize=14)
plt.xlabel('Reason')
plt.ylabel('Number of People')
plt.xticks(rotation=20)
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Display plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Most of the investors have short- or mid-term goals where they can't risk losing money and also are returns oriented .
# Investors rarely choose Tax incentives as their reason for saving this might be due to unawareness of tax saving benefits.

# %%
data['Reason_Equity'].value_counts()
# Out:
# Capital Appreciation    30
# Dividend                 8
# Liquidity                2
# Name: Reason_Equity, dtype: int64

# %%
import matplotlib.pyplot as plt

# Get the counts of each reason
equity_reasons = data['Reason_Equity'].value_counts()

# Plotting
plt.figure(figsize=(7, 5))
plt.bar(equity_reasons.index, equity_reasons.values, color='orange')

# Add labels and title
plt.title('Reasons for Investing in Equity', fontsize=14)
plt.xlabel('Reason')
plt.ylabel('Number of People')
plt.xticks(rotation=20)
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# This suggests most people in your dataset are:
#
# Growth-oriented investors.
#
# Likely willing to take on more risk for higher potential reward.
#
# Probably younger and have a longer investment horizon (they can afford to wait for long-term gains).

# %%
data['Reason_Mutual'].value_counts()
# Out:
# Better Returns          24
# Fund Diversification    13
# Tax Benefits             3
# Name: Reason_Mutual, dtype: int64

# %%
import matplotlib.pyplot as plt

# Get the value counts
mutual_reasons = data['Reason_Mutual'].value_counts()

# Plotting
plt.figure(figsize=(7, 5))
plt.bar(mutual_reasons.index, mutual_reasons.values, color='mediumslateblue')

# Adding titles and labels
plt.title('Reasons for Investing in Mutual Funds', fontsize=14)
plt.xlabel('Reason')
plt.ylabel('Number of People')
plt.xticks(rotation=20)
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Most people invest for better returns and funds diversification. They prefer spreading their money across different assets to reduce risks.

# %% [markdown]
# # Task 6: Savings Objectives

# %% [markdown]
# ## Rename column name What are your savings objectives?

# %%
data.rename(columns={'What are your savings objectives?': 'savings_objectives'}, inplace=True)

# %%
data['savings_objectives'].value_counts()
# Out:
# Retirement Plan    24
# Health Care        13
# Education           3
# Name: savings_objectives, dtype: int64

# %%
import matplotlib.pyplot as plt

# Get the value counts
savings_objectives = data['savings_objectives'].value_counts()

# Plotting
plt.figure(figsize=(7, 5))
plt.bar(savings_objectives.index, savings_objectives.values, color='blue')

# Adding titles and labels
plt.title('Reasons for Saving', fontsize=14)
plt.xlabel('Reason')
plt.ylabel('Number of People')
plt.xticks(rotation=20)
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Long-term financial independence is a major motivator.
#
# This tells us that most respondents are forward-thinking and understand the importance of saving early for their post-working years.

# %% [markdown]
# # Task 7: Common Information Sources

# %%
data['Source'].value_counts()
# Out:
# Financial Consultants       16
# Newspapers and Magazines    14
# Television                   6
# Internet                     4
# Name: Source, dtype: int64

# %%
import matplotlib.pyplot as plt

# Get the value counts
source_counts = data['Source'].value_counts()

# Plotting
plt.figure(figsize=(7, 5))
plt.bar(source_counts.index,source_counts.values, color='blue')

# Adding titles and labels
plt.title('Sources of Information', fontsize=14)
plt.xlabel('Source')
plt.ylabel('Counts')
plt.xticks(rotation=20)
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# People still trust human advice for financial decisions.
#
# Consultants offer personalized guidance, which is especially valuable in complex investment decisions.
#
# Suggests respondents might not feel fully confident making investment decisions on their own.

# %% [markdown]
# # Task 8: Investment Duration

# %%
data['Duration'].value_counts()
# Out:
# 3-5 years            19
# 1-3 years            18
# Less than 1 year      2
# More than 5 years     1
# Name: Duration, dtype: int64

# %%
import matplotlib.pyplot as plt

# Get the value counts
investment_duration = data['Duration'].value_counts()

# Plotting
plt.figure(figsize=(7, 5))
plt.bar(investment_duration.index,investment_duration.values, color='blue')

# Adding titles and labels
plt.title('Investment Duration', fontsize=14)
plt.xlabel('Duration')
plt.ylabel('Counts')
plt.xticks(rotation=20)
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There is dominance of Medium-Term Investments (3-5 years & 1-3 years).Most individuals prefer not to lock in funds for too long, but also want better returns than short-term options.

# %% [markdown]
# # Task 9: Expectations from Investments

# %%
expectation= data['Expect'].value_counts()
expectation
# Out:
# 20%-30%    32
# 30%-40%     5
# 10%-20%     3
# Name: Expect, dtype: int64

# %%
import matplotlib.pyplot as plt

# Get the value counts
expectation= data['Expect'].value_counts()

# Plotting
plt.figure(figsize=(7, 5))
plt.bar(expectation.index, expectation.values, color='blue')

# Adding titles and labels
plt.title('Expectation from Investment', fontsize=14)
plt.xlabel('Expectation')
plt.ylabel('Counts')
plt.xticks(rotation=20)
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Majority Expect 20%-30% Returns (80%).Most people expect aggressive growth — this might shape their risk appetite (leaning toward equity markets or mutual funds).

# %% [markdown]
# # Task 10: Correlation Analysis

# %%
numerical_columns = data[['age', 'Mutual_Funds', 'Equity_Market', 'Debentures','Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold']]

# %%
# Correlation matrix
correlation_matrix = numerical_columns.corr()
correlation_matrix
# Out:
#                        age  Mutual_Funds  Equity_Market  Debentures  \
# age               1.000000     -0.123914       0.246840    0.326638
# Mutual_Funds     -0.123914      1.000000       0.332043   -0.351495
# Equity_Market     0.246840      0.332043       1.000000   -0.016898
# Debentures        0.326638     -0.351495      -0.016898    1.000000
# Government_Bonds -0.093632     -0.114198      -0.237420    0.430323
# Fixed_Deposits   -0.033685     -0.031604      -0.238705   -0.470791
# PPF              -0.263167     -0.193665      -0.429003   -0.511169
# Gold             -0.057952     -0.401830      -0.050027   -0.137195
#
#                   Government_Bonds  Fixed_Deposits       PPF      Gold
# age                      -0.093632       -0.033685 -0.263167 -0.057952
# Mutual_Funds             -0.114198       -0.031604 -0.193665 -0.401830
# Equity_Market            -0.237420       -0.238705 -0.429003 -0.050027
# Debentures                0.430323       -0.470791 -0.511169 -0.137195
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Investment Options')
plt.show()

# %% [markdown]
# Based on the heatmap, Equity Market and Mutual Funds show a strong positive correlation, indicating that investors aiming for growth often prefer both. Conversely, risk-averse instruments like PPF and Fixed Deposits are negatively correlated with equities and debentures, reflecting conservative investor preferences. Age positively correlates with debentures and equity markets, suggesting older individuals lean toward more mature investments. Mutual Funds and Gold exhibit a strong negative correlation, highlighting differing risk appetites. Overall, investors tend to group their choices into either high-risk/high-return or low-risk/stable return categories.
